# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250
sns.set_style('darkgrid')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#read the data
df = pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# # EDA

# %%
#Data visualization

# %%
sns.pairplot(df)

# %%
cat_cols = df.select_dtypes(object).columns
cat_cols
# Out:
# Index(['State'], dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()

df[cat_cols] = oe.fit_transform(df[cat_cols])

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10    2.0  192261.83
# 1   162597.70       151377.59        443898.53    0.0  191792.06
# 2   153441.51       101145.55        407934.54    1.0  191050.39
# 3   144372.41       118671.85        383199.62    2.0  182901.99
# 4   142107.34        91391.77        366168.42    1.0  166187.94
# 5   131876.90        99814.71        362861.36    2.0  156991.12
# 6   134615.46       147198.87        127716.82    0.0  156122.51
# 7   130298.13       145530.06        323876.68    1.0  155752.60
# 8   120542.52       148718.95        311613.29    2.0  152211.77
# 9   123334.88       108679.17        304981.62    0.0  149759.96
# 10  101913.08       110594.11        229160.95    1.0  146121.95
# 11  100671.96        91790.61        249744.55    0.0  144259.40
# 12   93863.75       127320.38        249839.44    1.0  141585.52
# ...

# %%
#Correlation

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df.iloc[:, :-1] = sc.fit_transform(df.iloc[:,:-1])

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend     State     Profit
# 0    2.016411        0.560753         2.153943  1.212678  192261.83
# 1    1.955860        1.082807         1.923600 -1.212678  191792.06
# 2    1.754364       -0.728257         1.626528  0.000000  191050.39
# 3    1.554784       -0.096365         1.422210  1.212678  182901.99
# 4    1.504937       -1.079919         1.281528  0.000000  166187.94
# 5    1.279800       -0.776239         1.254210  1.212678  156991.12
# 6    1.340066        0.932147        -0.688150 -1.212678  156122.51
# 7    1.245057        0.871980         0.932186  0.000000  155752.60
# 8    1.030369        0.986952         0.830887  1.212678  152211.77
# 9    1.091819       -0.456640         0.776107 -1.212678  149759.96
# 10   0.620398       -0.387599         0.149807  0.000000  146121.95
# 11   0.593085       -1.065540         0.319834 -1.212678  144259.40
# 12   0.443260        0.215449         0.320617  0.000000  141585.52
# ...

# %%
df = df.rename(columns={'R&D Spend':'RDSpend', 'Marketing Spend':'MarketingSpend'})

# %%
df
# Out:
#      RDSpend  Administration  MarketingSpend     State     Profit
# 0   2.016411        0.560753        2.153943  1.212678  192261.83
# 1   1.955860        1.082807        1.923600 -1.212678  191792.06
# 2   1.754364       -0.728257        1.626528  0.000000  191050.39
# 3   1.554784       -0.096365        1.422210  1.212678  182901.99
# 4   1.504937       -1.079919        1.281528  0.000000  166187.94
# 5   1.279800       -0.776239        1.254210  1.212678  156991.12
# 6   1.340066        0.932147       -0.688150 -1.212678  156122.51
# 7   1.245057        0.871980        0.932186  0.000000  155752.60
# 8   1.030369        0.986952        0.830887  1.212678  152211.77
# 9   1.091819       -0.456640        0.776107 -1.212678  149759.96
# 10  0.620398       -0.387599        0.149807  0.000000  146121.95
# 11  0.593085       -1.065540        0.319834 -1.212678  144259.40
# 12  0.443260        0.215449        0.320617  0.000000  141585.52
# ...

# %% [markdown]
# # Model Building

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols('Profit~RDSpend+Administration+MarketingSpend+State',data=df).fit()

# %%
model.pvalues
# Out:
# Intercept         2.633432e-51
# RDSpend           8.249206e-22
# Administration    6.056771e-01
# MarketingSpend    1.086131e-01
# State             9.889988e-01
# dtype: float64

# %% [markdown]
# # Calculate VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.head()
# Out:
#     RDSpend  Administration  MarketingSpend     State     Profit
# 0  2.016411        0.560753        2.153943  1.212678  192261.83
# 1  1.955860        1.082807        1.923600 -1.212678  191792.06
# 2  1.754364       -0.728257        1.626528  0.000000  191050.39
# 3  1.554784       -0.096365        1.422210  1.212678  182901.99
# 4  1.504937       -1.079919        1.281528  0.000000  166187.94

# %%
data = df.drop(columns=['Profit'])
data
# Out:
#      RDSpend  Administration  MarketingSpend     State
# 0   2.016411        0.560753        2.153943  1.212678
# 1   1.955860        1.082807        1.923600 -1.212678
# 2   1.754364       -0.728257        1.626528  0.000000
# 3   1.554784       -0.096365        1.422210  1.212678
# 4   1.504937       -1.079919        1.281528  0.000000
# 5   1.279800       -0.776239        1.254210  1.212678
# 6   1.340066        0.932147       -0.688150 -1.212678
# 7   1.245057        0.871980        0.932186  0.000000
# 8   1.030369        0.986952        0.830887  1.212678
# 9   1.091819       -0.456640        0.776107 -1.212678
# 10  0.620398       -0.387599        0.149807  0.000000
# 11  0.593085       -1.065540        0.319834 -1.212678
# 12  0.443260        0.215449        0.320617  0.000000
# 13  0.402078        0.510179        0.343957 -1.212678
# 14  1.017181        1.269199        0.375742  0.000000
# 15  0.897913        0.045868        0.419219  1.212678
# ...

# %%
vif = pd.DataFrame()
vif
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
vif['Features'] = data.columns
vif
# Out:
#         VIF        Features
# 0  2.481178         RDSpend
# 1  1.175315  Administration
# 2  2.326780  MarketingSpend
# 3  1.011281           State

# %%
vif['VIF'] = [variance_inflation_factor(data.values,i) for i in range(len(data.columns))]

# %%
vif
# Out:
#         VIF        Features
# 0  2.481178         RDSpend
# 1  1.175315  Administration
# 2  2.326780  MarketingSpend
# 3  1.011281           State

# %% [markdown]
# # Subset Selection
#
# AIC

# %%
rd = smf.ols('Profit~RDSpend+Administration',data = df).fit()
rd.rsquared, rd.aic
# Out:
# (0.9478129385009173, 1059.6636934567296)

# %%
RD = smf.ols('Profit~RDSpend+State',data = df).fit()
RD.rsquared, RD.aic
# Out:
# (0.9465353188011284, 1060.8730270180974)

# %%
a = smf.ols('Profit~Administration+MarketingSpend',data = df).fit()
a.rsquared, a.aic
# Out:
# (0.6097229746770665, 1160.2648038638672)

# %%
M = smf.ols('Profit~MarketingSpend+State',data = df).fit()
M.rsquared, M.aic
# Out:
# (0.5610764067754652, 1166.1382309787127)

# %%
RDA = smf.ols('Profit~RDSpend+State+Administration',data = df).fit()
RDA.rsquared, RDA.aic
# Out:
# (0.9478132427746071, 1061.663401933727)

# %%
ms = smf.ols('Profit~MarketingSpend+State+Administration',data = df).fit()
ms.rsquared, ms.aic
# Out:
# (0.6113727245607464, 1162.0529996217995)

# %% [markdown]
# # MODEL VALIDATION TECHNIQUES

# %% [markdown]
# # Residual Analysis

# %%
model = smf.ols('Profit~RDSpend+State+Administration', data=df).fit()
model.rsquared
# Out:
# 0.9478132427746071

# %%
#Statsmodel
import statsmodels.api as sm

# %%
df.head()
# Out:
#     RDSpend  Administration  MarketingSpend     State     Profit
# 0  2.016411        0.560753        2.153943  1.212678  192261.83
# 1  1.955860        1.082807        1.923600 -1.212678  191792.06
# 2  1.754364       -0.728257        1.626528  0.000000  191050.39
# 3  1.554784       -0.096365        1.422210  1.212678  182901.99
# 4  1.504937       -1.079919        1.281528  0.000000  166187.94

# %%
model.resid
# Out:
# 0      2101.841376
# 1      4718.180257
# 2      9234.906845
# 3      9861.473800
# 4     -6372.571617
# 5     -6275.691917
# 6     -7047.404350
# 7     -3756.656552
# 8      1309.388101
# 9     -5725.977618
# 10     9233.605633
# 11     7417.557458
# 12    12523.678803
# 13     7265.414190
# 14   -17394.928595
# 15   -17179.605193
# 16    11266.855308
# 17    -3407.431675
# 18    -3668.557185
# 19     1548.348577
# 20     3854.972758
# 21    -2978.317017
# 22    -1819.484136
# 23     1230.830518
# 24    -7467.735445
# 25     4138.634589
# 26    -6456.729402
# 27    -5240.331400
# 28     1132.041430
# 29    -2304.013668
# 30    -2266.574188
# 31    -1989.466474
# 32    -5302.857426
# 33     -487.705162
# 34    10133.499518
# 35     6458.387051
# 36    17845.864130
# 37     -239.284221
# 38    12426.110935
# 39    -2750.600592
# 40     4821.559542
# 41     3356.500969
# 42     1303.719360
# 43     8285.247430
# 44     -625.844048
# 45    15787.390949
# 46     -388.471220
# ...

# %%
#Q-Q plot
sm.qqplot(model.resid, line = 'q');

# %%
#get index for higher residuals

# %%
np.argmax(model.resid), np.max(model.resid)
# Out:
# (36, 17845.864129801295)

# %% [markdown]
# # Residual plot of Homoscedasticity

# %%
df
# Out:
#      RDSpend  Administration  MarketingSpend     State     Profit
# 0   2.016411        0.560753        2.153943  1.212678  192261.83
# 1   1.955860        1.082807        1.923600 -1.212678  191792.06
# 2   1.754364       -0.728257        1.626528  0.000000  191050.39
# 3   1.554784       -0.096365        1.422210  1.212678  182901.99
# 4   1.504937       -1.079919        1.281528  0.000000  166187.94
# 5   1.279800       -0.776239        1.254210  1.212678  156991.12
# 6   1.340066        0.932147       -0.688150 -1.212678  156122.51
# 7   1.245057        0.871980        0.932186  0.000000  155752.60
# 8   1.030369        0.986952        0.830887  1.212678  152211.77
# 9   1.091819       -0.456640        0.776107 -1.212678  149759.96
# 10  0.620398       -0.387599        0.149807  0.000000  146121.95
# 11  0.593085       -1.065540        0.319834 -1.212678  144259.40
# 12  0.443260        0.215449        0.320617  0.000000  141585.52
# ...

# %%
model.params
# Out:
# Intercept         112012.639200
# RDSpend            39177.823979
# State                -22.133603
# Administration     -1470.209368
# dtype: float64

# %%
model.fittedvalues
# Out:
# 0     190159.988624
# 1     187073.879743
# 2     181815.483155
# 3     173040.516200
# 4     172560.511617
# 5     163266.811917
# 6     163169.914350
# 7     159509.256552
# 8     150902.381899
# 9     155485.937618
# 10    136888.344367
# 11    136841.842542
# 12    129061.841197
# 13    127041.935810
# 14    149997.578595
# 15    147096.645193
# 16    115726.074692
# 17    128777.801675
# 18    127935.457185
# 19    121228.511423
# 20    114619.057242
# 21    114291.337017
# 22    112171.734136
# 23    107503.159482
# 24    116019.775445
# 25    103265.705411
# 26    112190.269402
# 27    110248.641400
# 28    102150.338570
# 29    103308.653668
# 30    102204.164188
# 31     99473.026474
# 32    102730.697426
# 33     97266.625162
# 34     86579.300482
# 35     90021.122949
# 36     72862.325870
# 37     90188.424221
# 38     68802.949065
# 39     83756.360592
# 40     73418.350458
# 41     74442.329031
# 42     70194.770640
# 43     61473.732570
# 44     65826.174048
# ...

# %%
model.resid
# Out:
# 0      2101.841376
# 1      4718.180257
# 2      9234.906845
# 3      9861.473800
# 4     -6372.571617
# 5     -6275.691917
# 6     -7047.404350
# 7     -3756.656552
# 8      1309.388101
# 9     -5725.977618
# 10     9233.605633
# 11     7417.557458
# 12    12523.678803
# 13     7265.414190
# 14   -17394.928595
# 15   -17179.605193
# 16    11266.855308
# 17    -3407.431675
# 18    -3668.557185
# 19     1548.348577
# 20     3854.972758
# 21    -2978.317017
# 22    -1819.484136
# 23     1230.830518
# 24    -7467.735445
# 25     4138.634589
# 26    -6456.729402
# 27    -5240.331400
# 28     1132.041430
# 29    -2304.013668
# 30    -2266.574188
# 31    -1989.466474
# 32    -5302.857426
# 33     -487.705162
# 34    10133.499518
# 35     6458.387051
# 36    17845.864130
# 37     -239.284221
# 38    12426.110935
# 39    -2750.600592
# 40     4821.559542
# 41     3356.500969
# 42     1303.719360
# 43     8285.247430
# 44     -625.844048
# 45    15787.390949
# 46     -388.471220
# ...

# %%
plt.scatter(model.fittedvalues, model.resid)
plt.xlabel('Predicted Values')
plt.ylabel('Errors')
# Out:
# Text(0, 0.5, 'Errors')

# %% [markdown]
# # 3.Residual VS Regressor

# %%
sm.graphics.plot_regress_exog(model,'RDSpend');

# %% [markdown]
# # MODEL DELETION TECHNIQUES

# %% [markdown]
# # Cook's Distance

# %%
model

# %%
#Find the influence data
inf = model.get_influence()

#Calculate the cooks distance
c,p = inf.cooks_distance

# %%
c
# Out:
# array([1.93059621e-03, 1.21710195e-02, 3.30063895e-02, 3.12649943e-02,
#        1.56534802e-02, 1.35698281e-02, 1.70387795e-02, 2.56457947e-03,
#        4.35181555e-04, 1.00021914e-02, 8.58494284e-03, 1.69632513e-02,
#        1.10436628e-02, 9.62489156e-03, 6.02120114e-02, 5.75184827e-02,
#        1.96502224e-02, 2.34537768e-03, 1.01528522e-03, 5.90606505e-04,
#        2.38001265e-03, 2.25474710e-03, 1.91384459e-04, 1.16437297e-04,
#        1.10690396e-02, 3.19478608e-03, 4.21451940e-03, 4.34078320e-03,
#        5.98742298e-04, 1.43032361e-03, 3.23688268e-04, 1.09766985e-03,
#        4.48731321e-03, 2.09621928e-05, 3.42489161e-02, 1.22462662e-02,
#        4.25829856e-02, 4.09949704e-05, 8.46209425e-02, 2.24749277e-03,
#        4.76659441e-03, 2.32440468e-03, 4.30187106e-04, 2.22773887e-02,
#        1.60237250e-04, 1.01540252e-01, 3.49805648e-05, 1.04395252e-02,
#        2.55253301e-01, 3.74986289e-01])

# %%
# Cook's distance plot
plt.stem(c)
plt.xlabel('Index')
plt.ylabel('Cooks Distance')
# Out:
# Text(0, 0.5, 'Cooks Distance')

# %%
np.argmax(c), np.max(c)
# Out:
# (49, 0.3749862888222616)

# %%
df.iloc[[49]]
# Out:
#      RDSpend  Administration  MarketingSpend     State   Profit
# 49 -1.622362       -0.157226       -1.369985 -1.212678  14681.4

# %%
df.head()
# Out:
#     RDSpend  Administration  MarketingSpend     State     Profit
# 0  2.016411        0.560753        2.153943  1.212678  192261.83
# 1  1.955860        1.082807        1.923600 -1.212678  191792.06
# 2  1.754364       -0.728257        1.626528  0.000000  191050.39
# 3  1.554784       -0.096365        1.422210  1.212678  182901.99
# 4  1.504937       -1.079919        1.281528  0.000000  166187.94

# %%
#Influence Plot
from statsmodels.graphics.regressionplots import influence_plot

# %%
influence_plot(model);

# %%
#Calculate cutoff
k = len(df.columns)
n = len(df)

lv = 3*(k+1)/n
lv
# Out:
# 0.36

# %%
influence_plot(model)
plt.axvline(lv, linestyle = '--', color = 'red')

# %% [markdown]
# # Improving the model

# %%
df.drop(index=49,inplace=True)

# %%
df
# Out:
#      RDSpend  Administration  MarketingSpend     State     Profit
# 0   2.016411        0.560753        2.153943  1.212678  192261.83
# 1   1.955860        1.082807        1.923600 -1.212678  191792.06
# 2   1.754364       -0.728257        1.626528  0.000000  191050.39
# 3   1.554784       -0.096365        1.422210  1.212678  182901.99
# 4   1.504937       -1.079919        1.281528  0.000000  166187.94
# 5   1.279800       -0.776239        1.254210  1.212678  156991.12
# 6   1.340066        0.932147       -0.688150 -1.212678  156122.51
# 7   1.245057        0.871980        0.932186  0.000000  155752.60
# 8   1.030369        0.986952        0.830887  1.212678  152211.77
# 9   1.091819       -0.456640        0.776107 -1.212678  149759.96
# 10  0.620398       -0.387599        0.149807  0.000000  146121.95
# 11  0.593085       -1.065540        0.319834 -1.212678  144259.40
# 12  0.443260        0.215449        0.320617  0.000000  141585.52
# ...

# %%
#reset the index

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     index   RDSpend  Administration  MarketingSpend     State     Profit
# 0       0  2.016411        0.560753        2.153943  1.212678  192261.83
# 1       1  1.955860        1.082807        1.923600 -1.212678  191792.06
# 2       2  1.754364       -0.728257        1.626528  0.000000  191050.39
# 3       3  1.554784       -0.096365        1.422210  1.212678  182901.99
# 4       4  1.504937       -1.079919        1.281528  0.000000  166187.94
# 5       5  1.279800       -0.776239        1.254210  1.212678  156991.12
# 6       6  1.340066        0.932147       -0.688150 -1.212678  156122.51
# 7       7  1.245057        0.871980        0.932186  0.000000  155752.60
# 8       8  1.030369        0.986952        0.830887  1.212678  152211.77
# 9       9  1.091819       -0.456640        0.776107 -1.212678  149759.96
# 10     10  0.620398       -0.387599        0.149807  0.000000  146121.95
# 11     11  0.593085       -1.065540        0.319834 -1.212678  144259.40
# ...

# %%
df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#      RDSpend  Administration  MarketingSpend     State     Profit
# 0   2.016411        0.560753        2.153943  1.212678  192261.83
# 1   1.955860        1.082807        1.923600 -1.212678  191792.06
# 2   1.754364       -0.728257        1.626528  0.000000  191050.39
# 3   1.554784       -0.096365        1.422210  1.212678  182901.99
# 4   1.504937       -1.079919        1.281528  0.000000  166187.94
# 5   1.279800       -0.776239        1.254210  1.212678  156991.12
# 6   1.340066        0.932147       -0.688150 -1.212678  156122.51
# 7   1.245057        0.871980        0.932186  0.000000  155752.60
# 8   1.030369        0.986952        0.830887  1.212678  152211.77
# 9   1.091819       -0.456640        0.776107 -1.212678  149759.96
# 10  0.620398       -0.387599        0.149807  0.000000  146121.95
# 11  0.593085       -1.065540        0.319834 -1.212678  144259.40
# 12  0.443260        0.215449        0.320617  0.000000  141585.52
# ...

# %%
final_model = smf.ols('Profit~RDSpend+State+Administration', data = df).fit()

# %%
final_model.rsquared
# Out:
# 0.9589084115933707
